# %%
import pandas as pd
import numpy as np
import csv
import re
import unicodedata
import math
from tqdm import tqdm

from fuzzywuzzy import fuzz, process
from ast import literal_eval

# %%
data = pd.read_csv('brand_train.csv')

data = data[['name','brand']]
print('資料總筆數:', len(data))
print('品牌總數:', len(data['brand'].unique()))
# Out:
# 資料總筆數: 70046
# 品牌總數: 4068

# %%
# 全形轉半形
def strQ2B(ustring):
    rstring = ""
    for uchar in ustring:
        inside_code = ord(uchar)
        if inside_code == 12288:                            # 全形空格直接轉換
            inside_code = 32
        elif 65281 <= inside_code <= 65374:                # 全形字元（除空格）根據關係轉化
            inside_code -= 65248
        rstring += chr(inside_code)
    return rstring

# %%
# 拉丁語系轉換，如:biore
def reverse(x: str):
    return ''.join(c for c in unicodedata.normalize('NFD', x)
                  if unicodedata.category(c) != 'Mn')

# %%
# 品牌大寫轉小寫
data['brand'] = data['brand'].str.lower()

for i in tqdm(range(len(data))):
    try:
        data['brand'][i] = reverse(strQ2B(data['brand'][i]))
    except:
        pass
# Out:
# 100%|██████████████████████████████████| 70046/70046 [00:06<00:00, 11544.90it/s]

# %%
oribrand = pd.DataFrame(data['brand'].unique(), columns = ['original_brand'])
oribrand
# Out:
#              original_brand
# 0                        元山
# 1                       姍拉娜
# 2                        台鹽
# 3               neo-tec妮傲絲翠
# 4                        舒潔
# ...                     ...
# 3969  smith's rosebud salve
# 3970                van pur
# 3971            sweep robot
# 3972          malibu beauty
# 3973           s.pellegrino
#
# [3974 rows x 1 columns]

# %% [markdown]
# # 整理品牌名單

# %%
presave = oribrand.copy(deep=True)

# %%
brand_list = presave.copy(deep=True)

# %% [markdown]
# ## 1. 單一品牌名單（全小寫，順序英+中）

# %%
brand_list
# Out:
#              original_brand
# 0                        元山
# 1                       姍拉娜
# 2                        台鹽
# 3               neo-tec妮傲絲翠
# 4                        舒潔
# ...                     ...
# 3969  smith's rosebud salve
# 3970                van pur
# 3971            sweep robot
# 3972          malibu beauty
# 3973           s.pellegrino
#
# [3974 rows x 1 columns]

# %%
brand_list['brand_ch'] = ''
brand_list['brand_en'] = ''
brand_list['cleaned_brand'] = ''

for i in tqdm(range(len(brand_list))):
    dtxt = brand_list['original_brand'][i]
    
    if not dtxt.isnumeric():
        # 提出中文
        try:
            # 先提出中英複合詞，e.g. 阿q桶麵, 台灣g霸
            brand_list['brand_ch'][i] = re.search(u"[\u4e00-\u9fa5]+[\u0061-\u007a]+[\u4e00-\u9fa5]+", dtxt).group()
        except AttributeError:
            # 刪除英文字符
            brand_list['brand_ch'][i] = re.sub("( |~|-|·|‧|'|\.|\d+|[0-9]+\.[0-9])?[\u0061-\u007a](~| |-|·|‧|'|\.|!|’|&|/|:)?( |\d+|\+|[0-9]+\.[0-9]|&)?", "", dtxt)

        try:
            # 確認架構是否為中+數字+英 或 英+數字+中
            tmp = re.search(u"[\u4e00-\u9fa5]+( )?\d+( )?[\u0061-\u007a]+|[\u0061-\u007a]+( )?\d+( )?[\u4e00-\u9fa5]+", dtxt).group()
            brand_list['brand_en'][i] = re.sub("( |\d+|[0-9]+\.[0-9])?[\u4e00-\u9fa5]+[\u0061-\u007a]+[\u4e00-\u9fa5]+( )?|( )?[\u4e00-\u9fa5]+(~| |-|·|‧)?", "", dtxt)
        except AttributeError:
            # 提出英文
            brand_list['brand_en'][i] = re.sub("( |\d+|[0-9]+\.[0-9])?[\u4e00-\u9fa5]+[\u0061-\u007a]+[\u4e00-\u9fa5]+( )?|( |\d+|[0-9]+\.[0-9])?[\u4e00-\u9fa5]+(~| |-|·|‧|±|[0-9]+\.[0-9])?(\d+|\+)?", "", dtxt)
        
        brand_list['cleaned_brand'][i] = brand_list['brand_en'][i]+brand_list['brand_ch'][i]
        
    else:
        brand_list['cleaned_brand'][i] = dtxt
        pass

brand_list
# Out:
# 100%|█████████████████████████████████████| 3974/3974 [00:01<00:00, 3517.46it/s]
#              original_brand brand_ch               brand_en  \
# 0                        元山       元山
# 1                       姍拉娜      姍拉娜
# 2                        台鹽       台鹽
# 3               neo-tec妮傲絲翠     妮傲絲翠                neo-tec
# 4                        舒潔       舒潔
# ...                     ...      ...                    ...
# 3969  smith's rosebud salve           smith's rosebud salve
# 3970                van pur                         van pur
# 3971            sweep robot                     sweep robot
# 3972          malibu beauty                   malibu beauty
# 3973           s.pellegrino                    s.pellegrino
#
#               cleaned_brand
# 0                        元山
# 1                       姍拉娜
# 2                        台鹽
# 3               neo-tec妮傲絲翠
# 4                        舒潔
# ...                     ...
# 3969  smith's rosebud salve
# 3970                van pur
# 3971            sweep robot
# 3972          malibu beauty
# 3973           s.pellegrino
#
# [3974 rows x 4 columns]

# %% [markdown]
# ### ----------
# ### 暫時存檔（依英文順序排列）

# %%
print('單一品牌總數:', len(brand_list['original_brand'].unique()))
print('英文切割總數:', len(brand_list['brand_ch'].unique()))
print('中文切割總數:', len(brand_list['brand_en'].unique()))
# Out:
# 單一品牌總數: 3974
# 英文切割總數: 2385
# 中文切割總數: 2377

# %%
sr = brand_list.sort_values('brand_en', ascending=True)
sr
# Out:
#      original_brand brand_ch  brand_en cleaned_brand
# 0                元山       元山                      元山
# 1946            金安心      金安心                     金安心
# 1943             虎屋       虎屋                      虎屋
# 1936             阿娟       阿娟                      阿娟
# 1935           戀戀情人     戀戀情人                    戀戀情人
# ...             ...      ...       ...           ...
# 3821        zoobies            zoobies       zoobies
# 103        卓威 zowie       卓威     zowie       zowie卓威
# 2699    日象 zushiang       日象  zushiang    zushiang日象
# 1383  德國雙人 zwilling     德國雙人  zwilling  zwilling德國雙人
# 3242          ‎d-up        ‎     ‎d-up        ‎d-up‎
#
# [3974 rows x 4 columns]

# %%
sr.to_csv('./temp/check_brand.csv')

# %% [markdown]
# ## -----

# %% [markdown]
# ## 2. 相關性處理

# %% [markdown]
# 1. 同品牌但涵蓋範圍不同
# 2. 純英文與英文加中文 e.g. adidas adidas愛迪達
# 3. 中文名稱與英文加中文 e.g. 愛迪達 adidas愛迪達
# 4. 英文與譯名 e.g. adidas 愛迪達 (只能從adidas愛迪達 推斷)

# %%
print('單一品牌總數:', len(brand_list['original_brand'].unique()))
print("清理後品牌總數:", len(brand_list['cleaned_brand'].unique()))
# Out:
# 單一品牌總數: 3974
# 清理後品牌總數: 3865

# %%
clunibrand = brand_list.drop_duplicates(subset=['cleaned_brand'],keep='first').reset_index()
clunibrand = clunibrand[['cleaned_brand']]
clunibrand
# Out:
#               cleaned_brand
# 0                        元山
# 1                       姍拉娜
# 2                        台鹽
# 3               neo-tec妮傲絲翠
# 4                        舒潔
# ...                     ...
# 3860  smith's rosebud salve
# 3861                van pur
# 3862            sweep robot
# 3863          malibu beauty
# 3864           s.pellegrino
#
# [3865 rows x 1 columns]

# %%
cbrand = clunibrand.copy(deep=True)
cbrandls = clunibrand.copy(deep=True)['cleaned_brand'].tolist()

# %%
cbrand['sim'] = cbrand['cleaned_brand'].apply(lambda x: process.extractBests(x, cbrandls, scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=50))

# %%
cbrand
# Out:
#               cleaned_brand  \
# 0                        元山
# 1                       姍拉娜
# 2                        台鹽
# 3               neo-tec妮傲絲翠
# 4                        舒潔
# ...                     ...
# 3860  smith's rosebud salve
# 3861                van pur
# 3862            sweep robot
# 3863          malibu beauty
# 3864           s.pellegrino
#
#                                                     sim      certain
# 0     [(元山牌, 80), (泰山, 50), (雪山, 50), (香山, 50), (山森,...  [(元山牌, 80)]
# 1                                                    []           []
# 2     [(台鹽生技, 67), (台酒, 50), (台啤, 50), (台農, 50), (臺鹽...           []
# 3                 [(neostrata芯絲翠, 52), (neocell妮兒, 50)]           []
# 4     [(舒跑, 50), (朵舒, 50), (舒澡, 50), (潔倍, 50), (潔芬, ...           []
# ...                                                 ...          ...
# 3860                                                 []           []
# 3861  [(pureal, 62), (urban veda, 59), (tarn ju, 57)...           []
# 3862  [(irobot, 59), (rosette, 56), (brook’s, 56), (...           []
# 3863  [(mandom beauty, 69), (pure beauty, 67), (beau...           []
# 3864  [(allegrini, 67), (cheerios, 60), (eilles, 56)...           []
#
# [3865 rows x 3 columns]

# %%
cbrand['certain'] = ''
for i in tqdm(range(len(cbrand))):
    tmplst = []
    ctlt = []
    for name , score in cbrand['sim'][i]:
        if score == 100:
            continue
        elif score >= 80:
            ctlt.append((name, score))
        tmplst.append((name, score))
    cbrand['sim'][i] = tmplst
    cbrand['certain'][i] = ctlt
# Out:
# 100%|█████████████████████████████████████| 3865/3865 [00:00<00:00, 5743.24it/s]

# %% [markdown]
# ### 轉出做人工判定

# %%
cbrand = cbrand[['cleaned_brand', 'certain', 'sim']]
cbrand.to_csv('./temp/checklist.csv')

# %%
len(cbrand.loc[cbrand['sim'].str.len() != 0])
# Out:
# 3217

# %%
ts = pd.read_csv('brand_zhen.csv')
ts
# Out:
#        Unnamed: 0                             name         brand
# 0               0                     元山熱水瓶ys540ap            元山
# 1               1                         姍拉娜治痘洗面乳           姍拉娜
# 2               2                        台鹽海洋鹼性離子水            台鹽
# 3               3                     妮傲絲翠果酸深層保養乳液   neo-tec妮傲絲翠
# 4               4                  舒潔棉柔舒適迪士尼抽取式衛生紙            舒潔
# ...           ...                              ...           ...
# 70041       70041  惠而浦16公斤瓦斯型滾筒蒸氣可堆疊乾衣機8twgd6622hw  whirlpool惠而浦
# 70042       70042                        康乃馨成人紙尿褲l           康乃馨
# 70043       70043                  日本芮芙茹零矽靈洗髮露頭皮保養     reveur芮芙茹
# 70044       70044                  crest長效鎖白牙膏輕柔鑽白      crestnan
# 70045       70045                      雀巢咖啡三合一義式拿鐵            雀巢
#
# [70046 rows x 3 columns]

# %%
ts = ts[['name','brand']]
print('資料總筆數:', len(ts))
print('品牌總數:', len(ts['brand'].unique()))
# Out:
# 資料總筆數: 70046
# 品牌總數: 3858

# %%
ts['brand_ch'] = ''
ts['brand_en'] = ''

for i in tqdm(range(len(brand_list))):
# Out:
#                                   name         brand
# 0                         元山熱水瓶ys540ap            元山
# 1                             姍拉娜治痘洗面乳           姍拉娜
# 2                            台鹽海洋鹼性離子水            台鹽
# 3                         妮傲絲翠果酸深層保養乳液   neo-tec妮傲絲翠
# 4                      舒潔棉柔舒適迪士尼抽取式衛生紙            舒潔
# ...                                ...           ...
# 70041  惠而浦16公斤瓦斯型滾筒蒸氣可堆疊乾衣機8twgd6622hw  whirlpool惠而浦
# 70042                        康乃馨成人紙尿褲l           康乃馨
# 70043                  日本芮芙茹零矽靈洗髮露頭皮保養     reveur芮芙茹
# 70044                  crest長效鎖白牙膏輕柔鑽白      crestnan
# 70045                      雀巢咖啡三合一義式拿鐵            雀巢
#
# [70046 rows x 2 columns]

# %% [markdown]
# ## ---

# %% [markdown]
# ## 中對中檢查

# %%
testb = brand_list.drop_duplicates(subset=['cleaned_brand'],keep='first').reset_index()
testb = testb[['brand_ch','brand_en','cleaned_brand']]
testb
# Out:
#      brand_ch               brand_en          cleaned_brand
# 0          元山                                            元山
# 1         姍拉娜                                           姍拉娜
# 2          台鹽                                            台鹽
# 3        妮傲絲翠                neo-tec            neo-tec妮傲絲翠
# 4          舒潔                                            舒潔
# ...       ...                    ...                    ...
# 3860           smith's rosebud salve  smith's rosebud salve
# 3861                         van pur                van pur
# 3862                     sweep robot            sweep robot
# 3863                   malibu beauty          malibu beauty
# 3864                    s.pellegrino           s.pellegrino
#
# [3865 rows x 3 columns]

# %%
chtest = testb[(testb['brand_ch'] != '') & (testb['brand_en'] == '')]

# %%
chtest['sim'] = chtest['brand_ch'].apply(lambda x: process.extractBests(x, chtest['brand_ch'].tolist(), scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=50))
chtest
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/880338855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chtest['sim'] = chtest['brand_ch'].apply(lambda x: process.extractBests(x, chtest['brand_ch'].tolist(), scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=50))
#      brand_ch brand_en cleaned_brand  \
# 0          元山                     元山
# 1         姍拉娜                    姍拉娜
# 2          台鹽                     台鹽
# 4          舒潔                     舒潔
# 9         龜甲萬                    龜甲萬
# ...       ...      ...           ...
# 3842       華菱                     華菱
# 3845       台塩                     台塩
# 3847       上元                     上元
# 3848    富基-10                  富基-10
# 3855     一午一食                   一午一食
#
#                                                     sim
# 0     [(元山, 100), (元山牌, 80), (泰山, 50), (雪山, 50), (香山...
# 1                                          [(姍拉娜, 100)]
# 2     [(台鹽, 100), (台鹽生技, 67), (台酒, 50), (台啤, 50), (台...
# 4     [(舒潔, 100), (舒跑, 50), (朵舒, 50), (舒澡, 50), (潔倍,...
# 9                                          [(龜甲萬, 100)]
# ...                                                 ...
# 3842  [(華菱, 100), (華佗, 50), (華陀, 50), (富華, 50), (華冠,...
# 3845  [(台塩, 100), (台鹽, 50), (台酒, 50), (台啤, 50), (台農,...
# 3847  [(上元, 100), (元山, 50), (上豪, 50), (東元, 50), (上田,...
# 3848                                     [(富基-10, 100)]
# 3855                                      [(一午一食, 100)]
#
# [1375 rows x 4 columns]

# %%
chtest.reset_index(inplace=True)
chtest = chtest[['brand_ch','brand_en','sim','cleaned_brand']]

# %%
chtest
# Out:
#      brand_ch brand_en cleaned_brand  \
# 0          元山                     元山
# 1         姍拉娜                    姍拉娜
# 2          台鹽                     台鹽
# 3          舒潔                     舒潔
# 4         龜甲萬                    龜甲萬
# ...       ...      ...           ...
# 1370       華菱                     華菱
# 1371       台塩                     台塩
# 1372       上元                     上元
# 1373    富基-10                  富基-10
# 1374     一午一食                   一午一食
#
#                                                     sim
# 0     [(元山牌, 80), (泰山, 50), (雪山, 50), (香山, 50), (山森,...
# 1                                                    []
# 2     [(台鹽生技, 67), (台酒, 50), (台啤, 50), (台農, 50), (臺鹽...
# 3     [(舒潔, 100), (舒跑, 50), (朵舒, 50), (舒澡, 50), (潔倍,...
# 4                                          [(龜甲萬, 100)]
# ...                                                 ...
# 1370  [(華菱, 100), (華佗, 50), (華陀, 50), (富華, 50), (華冠,...
# 1371  [(台塩, 100), (台鹽, 50), (台酒, 50), (台啤, 50), (台農,...
# 1372  [(上元, 100), (元山, 50), (上豪, 50), (東元, 50), (上田,...
# 1373                                     [(富基-10, 100)]
# 1374                                      [(一午一食, 100)]
#
# [1375 rows x 4 columns]

# %%
chtest['certain'] = ''
chtest['U'] = 0
for i in tqdm(range(len(chtest))):
    tmplst = []
    ctlt = []
    for name , score in chtest['sim'][i]:
        if score == 100:
            continue
        elif score >= 80:
            ctlt.append((name, score))
        tmplst.append((name, score))
    if len(ctlt) != 0:
        chtest['U'][i] = 1
    chtest['sim'][i] = tmplst
    chtest['certain'][i] = ctlt

chtest
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2500408812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chtest['certain'] = ''
#   0%|                                                  | 0/1375 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2500408812.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chtest['sim'][i] = tmplst
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2500408812.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chtest['certain'][i] = ctlt
# 100%|██████████████████████████████████████| 1375/1375 [00:07<00:00, 182.15it/s]
#      brand_ch brand_en cleaned_brand  \
# 0          元山                     元山
# 1         姍拉娜                    姍拉娜
# 2          台鹽                     台鹽
# 3          舒潔                     舒潔
# 4         龜甲萬                    龜甲萬
# ...       ...      ...           ...
# 1370       華菱                     華菱
# 1371       台塩                     台塩
# 1372       上元                     上元
# 1373    富基-10                  富基-10
# 1374     一午一食                   一午一食
#
#                                                     sim      certain
# 0     [(元山牌, 80), (泰山, 50), (雪山, 50), (香山, 50), (山森,...  [(元山牌, 80)]
# 1                                                    []           []
# 2     [(台鹽生技, 67), (台酒, 50), (台啤, 50), (台農, 50), (臺鹽...           []
# 3     [(舒跑, 50), (朵舒, 50), (舒澡, 50), (潔倍, 50), (潔芬, ...           []
# 4                                                    []           []
# ...                                                 ...          ...
# 1370  [(華佗, 50), (華陀, 50), (富華, 50), (華冠, 50), (西華, ...           []
# 1371  [(台鹽, 50), (台酒, 50), (台啤, 50), (台農, 50), (台畜, ...           []
# 1372  [(元山, 50), (上豪, 50), (東元, 50), (上田, 50), (山元, ...           []
# 1373                                                 []           []
# 1374                                                 []           []
#
# [1375 rows x 5 columns]

# %%
# 轉出做人工
chtest.to_csv('./temp/chtest.csv')

# %%
finzh = pd.read_csv('./temp/finchtest.csv', converters={"certain": literal_eval})

# %%
finzh = finzh[finzh['U'] != 2]
finzh.reset_index(inplace=True)
finzh = finzh[['brand_ch','certain','U']]
print('中文名稱總數:', len(finzh))
# Out:
# 中文名稱總數: 1306

# %%
# 整理中文資料

for i in tqdm(range(len(finzh))):
    namelst = []
    for name, score in finzh['certain'][i]:
        namelst.append(name)
    finzh['certain'][i] = namelst
finzh
# Out:
#   0%|                                                  | 0/1306 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3971014206.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finzh['certain'][i] = namelst
# 100%|██████████████████████████████████████| 1306/1306 [00:03<00:00, 356.45it/s]
#      brand_ch                         certain  U
# 0          元山                           [元山牌]  1
# 1         姍拉娜                              []  0
# 2          台鹽                        [臺鹽, 台塩]  1
# 3          舒潔                              []  0
# 4         龜甲萬                              []  0
# ...       ...                             ... ..
# 1301       華菱                              []  0
# 1302       上元                              []  0
# 1303    富基-10                              []  0
# 1304     一午一食                              []  0
# 1305       光泉  [光泉乳香世家, 光泉豆漿, 光泉頂級鮮奶優酪, 光泉鮮乳]  1
#
# [1306 rows x 3 columns]

# %%
finzh.to_csv('./temp/已檢查僅中文.csv')

# %% [markdown]
# ## -----

# %% [markdown]
# ## 英對英檢查

# %%
entest = testb[(testb['brand_ch'] == '') & (testb['brand_en'] != '')]
print('僅英文名稱總數:', len(entest))
# Out:
# 僅英文名稱總數: 1267

# %%
entest['sim'] = entest['brand_en'].apply(lambda x: process.extractBests(x, entest['brand_en'].tolist(), scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=50))
entest
# Out:
#                    brand_en  \
# 0                    refine
# 1                  i'm meme
# 2                    chicco
# 3                     kirin
# 4                   cezanne
# ...                     ...
# 1262  smith's rosebud salve
# 1263                van pur
# 1264            sweep robot
# 1265          malibu beauty
# 1266           s.pellegrino
#
#                                                     sim  \
# 0     [(refine, 100), (lirene, 67), (fine color, 62)...
# 1             [(i'm meme, 100), (heme, 50), (idee, 50)]
# 2     [(chicco, 100), (ok choice, 67), (maychic, 62)...
# 3     [(kirin, 100), (kiki, 67), (iris, 67), (i-kire...
# 4     [(cezanne, 100), (enne, 73), (ehrmann, 57), (b...
# ...                                                 ...
# 1262                     [(smith's rosebud salve, 100)]
# 1263  [(van pur, 100), (pureal, 62), (urban veda, 59...
# 1264  [(sweep robot, 100), (irobot, 59), (rosette, 5...
# 1265  [(malibu beauty, 100), (mandom beauty, 69), (p...
# 1266  [(s.pellegrino, 100), (allegrini, 67), (cheeri...
#
#               cleaned_brand certain  check
# 0                    refine      []      1
# 1                  i'm meme      []      1
# 2                    chicco      []      1
# 3                     kirin      []      1
# 4                   cezanne      []      1
# ...                     ...     ...    ...
# 1262  smith's rosebud salve      []      0
# 1263                van pur      []      1
# 1264            sweep robot      []      1
# 1265          malibu beauty      []      1
# 1266           s.pellegrino      []      1
#
# [1267 rows x 5 columns]

# %%
entest.reset_index(inplace=True)
entest = entest[['brand_en','sim','cleaned_brand']]

# %%
entest['certain'] = ''
entest['check'] = 0
for i in tqdm(range(len(entest))):
    tmplst = []
    ctlt = []
    for name , score in entest['sim'][i]:
        if score == 100:
            continue
        elif score >= 80:
            ctlt.append((name, score))
        tmplst.append((name, score))
    if len(ctlt) != 0:
        entest['check'][i] = 1
    entest['sim'][i] = tmplst
    entest['certain'][i] = ctlt

entest
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/914895896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entest['certain'] = ''
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/914895896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entest['check'] = 0
#   0%|                                                  | 0/1267 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/914895896.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entest['sim'][i] = tmplst
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/914895896.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entest['certain'][i] = ctlt
#   1%|▎                                         | 8/1267 [00:00<00:17, 73.92it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/914895896.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   entest['check'][i] = 1
# 100%|███████████████████████████████████████| 1267/1267 [00:14<00:00, 87.01it/s]
#                    brand_en  \
# 0                    refine
# 1                  i'm meme
# 2                    chicco
# 3                     kirin
# 4                   cezanne
# ...                     ...
# 1262  smith's rosebud salve
# 1263                van pur
# 1264            sweep robot
# 1265          malibu beauty
# 1266           s.pellegrino
#
#                                                     sim  \
# 0     [(lirene, 67), (fine color, 62), (fresh line, ...
# 1                              [(heme, 50), (idee, 50)]
# 2     [(ok choice, 67), (maychic, 62), (chacott, 62)...
# 3     [(kiki, 67), (iris, 67), (i-kirei, 67), (orion...
# 4     [(enne, 73), (ehrmann, 57), (beanies, 57), (co...
# ...                                                 ...
# 1262                                                 []
# 1263  [(pureal, 62), (urban veda, 59), (tarn ju, 57)...
# 1264  [(irobot, 59), (rosette, 56), (brook’s, 56), (...
# 1265  [(mandom beauty, 69), (pure beauty, 67), (beau...
# 1266  [(allegrini, 67), (cheerios, 60), (eilles, 56)...
#
#               cleaned_brand certain  check
# 0                    refine      []      0
# 1                  i'm meme      []      0
# 2                    chicco      []      0
# 3                     kirin      []      0
# 4                   cezanne      []      0
# ...                     ...     ...    ...
# 1262  smith's rosebud salve      []      0
# 1263                van pur      []      0
# 1264            sweep robot      []      0
# 1265          malibu beauty      []      0
# 1266           s.pellegrino      []      0
#
# [1267 rows x 5 columns]

# %%
entest.to_csv('./temp/entest.csv')

# %%
finen = pd.read_csv('./temp/finentest.csv', converters={"certain": literal_eval})
finen = finen[finen['check'] != 2]
finen.reset_index(inplace=True)
finen = finen[['brand_en','certain','check']]
print('英文名稱總數:', len(finzh))
# Out:
# 英文名稱總數: 1306

# %%
# 整理英文資料

for i in tqdm(range(len(finen))):
    namelst = []
    for name, score in finen['certain'][i]:
        namelst.append(name)
    finen['certain'][i] = namelst
finen
# Out:
#   0%|                                                  | 0/1259 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2956559732.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   finen['certain'][i] = namelst
# 100%|██████████████████████████████████████| 1259/1259 [00:03<00:00, 360.75it/s]
#            brand_en                   certain  check
# 0            refine                        []      0
# 1          i'm meme                        []      0
# 2            chicco                        []      0
# 3             kirin                        []      0
# 4           cezanne                        []      0
# ...             ...                       ...    ...
# 1254        van pur                        []      0
# 1255    sweep robot                        []      0
# 1256  malibu beauty                        []      0
# 1257   s.pellegrino                        []      0
# 1258        plantur  [plantur 21, plantur 39]      0
#
# [1259 rows x 3 columns]

# %%
finen.to_csv('./temp/已檢查僅英文.csv', encoding="utf-8")

# %% [markdown]
# ## --

# %% [markdown]
# ## 中英比對僅中文或僅英文

# %%
bttest = testb[(testb['brand_ch'] != '') & (testb['brand_en'] != '')]
print('中英名稱總數:', len(bttest))
# Out:
# 中英名稱總數: 1217

# %%
bttest = bttest.reset_index()
bttest = bttest[['brand_ch','brand_en','cleaned_brand']]

# %% [markdown]
# ### 中文比對

# %%
bttest['sim_ch'] = bttest['brand_ch'].apply(lambda x: process.extractBests(x, finzh['brand_ch'].tolist(), scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=90))
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '+']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '‘']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '‎']

# %%
bttest
# Out:
#      brand_ch            brand_en          cleaned_brand        sim_ch
# 0        妮傲絲翠             neo-tec            neo-tec妮傲絲翠            []
# 1         飛利浦             philips             philips飛利浦  [(飛利浦, 100)]
# 2          專科               senka                senka專科   [(專科, 100)]
# 3          芳珂               fancl                fancl芳珂            []
# 4          紅牛            red bull             red bull紅牛   [(紅牛, 100)]
# ...       ...                 ...                    ...           ...
# 1212       樂格                 log                  log樂格            []
# 1213     陪心寵糧              nu4pet             nu4pet陪心寵糧            []
# 1214       渴達              tundra               tundra渴達            []
# 1215      御皇居               royal               royal御皇居  [(御皇居, 100)]
# 1216      百貓喜  best feline friend  best feline friend百貓喜            []
#
# [1217 rows x 4 columns]

# %%
# bttest.to_csv('./temp/simch.csv')

# %% [markdown]
# ### 中+英 檢查中文是否有重複並標記

# %% [markdown]
# 中文重複

# %%
rpls = bttest[bttest.duplicated('brand_ch')]['brand_ch'].to_list()

# %%
bttest['repeat'] = 0
for i in range(len(bttest)):
    if bttest['brand_ch'][i] in rpls:
        bttest['repeat'][i] = 1
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3871935989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bttest['repeat'][i] = 1

# %%
bttest.to_csv('./temp/chsame.csv')

# %%
bttest = pd.read_csv('./temp/chrped.csv', converters={"sim_ch": literal_eval})
bttest = bttest[['brand_ch','brand_en','cleaned_brand','sim_ch','repeat']]

# %%
# 整理中+英 比對 中文資料

for i in tqdm(range(len(bttest))):
    namelst = []
    for name, score in bttest['sim_ch'][i]:
        namelst.append(name)
    bttest['sim_ch'][i] = namelst
bttest
# Out:
#   0%|                                                  | 0/1217 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2783827146.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bttest['sim_ch'][i] = namelst
# 100%|██████████████████████████████████████| 1217/1217 [00:03<00:00, 356.52it/s]
#      brand_ch            brand_en          cleaned_brand sim_ch  repeat
# 0        妮傲絲翠             neo-tec            neo-tec妮傲絲翠     []       0
# 1         飛利浦             philips             philips飛利浦  [飛利浦]       0
# 2          專科               senka                senka專科   [專科]       0
# 3          芳珂               fancl                fancl芳珂     []       0
# 4          紅牛            red bull             red bull紅牛     []       0
# ...       ...                 ...                    ...    ...     ...
# 1212       樂格                 log                  log樂格     []       0
# 1213     陪心寵糧              nu4pet             nu4pet陪心寵糧     []       0
# 1214       渴達              tundra               tundra渴達     []       0
# 1215      御皇居               royal               royal御皇居  [御皇居]       0
# 1216      百貓喜  best feline friend  best feline friend百貓喜     []       0
#
# [1217 rows x 5 columns]

# %%
print('比對中文後總數：',len(bttest[bttest['repeat'] == 0]))
# Out:
# 比對中文後總數： 1186

# %% [markdown]
# ### 英文比對

# %%
bttest['sim_en'] = bttest['brand_en'].apply(lambda x: process.extractBests(x, finen['brand_en'].tolist(), scorer=fuzz.token_sort_ratio, limit=20, score_cutoff=80))

# %%
bttest
# Out:
#      brand_ch            brand_en          cleaned_brand sim_ch  repeat  \
# 0        妮傲絲翠             neo-tec            neo-tec妮傲絲翠     []       0
# 1         飛利浦             philips             philips飛利浦  [飛利浦]       0
# 2          專科               senka                senka專科   [專科]       0
# 3          芳珂               fancl                fancl芳珂     []       0
# 4          紅牛            red bull             red bull紅牛     []       0
# ...       ...                 ...                    ...    ...     ...
# 1212       樂格                 log                  log樂格     []       0
# 1213     陪心寵糧              nu4pet             nu4pet陪心寵糧     []       0
# 1214       渴達              tundra               tundra渴達     []       0
# 1215      御皇居               royal               royal御皇居  [御皇居]       0
# 1216      百貓喜  best feline friend  best feline friend百貓喜     []       0
#
#               sim_en
# 0                 []
# 1                 []
# 2                 []
# 3     [(fancl, 100)]
# 4                 []
# ...              ...
# 1212      [(lg, 80)]
# 1213              []
# 1214              []
# 1215              []
# 1216              []
#
# [1217 rows x 6 columns]

# %%
rplsen = bttest[bttest.duplicated('brand_en')]['brand_en'].to_list()

# %%
bttest['repeaten'] = 0
for i in range(len(bttest)):
    if bttest['brand_en'][i] in rplsen:
        bttest['repeaten'][i] = 1
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2188847983.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bttest['repeaten'][i] = 1

# %%
bttest.to_csv('./temp/ensame.csv')

# %%
enchdf = pd.read_csv('./temp/enchreped.csv', converters={"sim_ch": literal_eval, "sim_en": literal_eval})
enchdf = enchdf[['brand_ch','brand_en','cleaned_brand','sim_ch','repeat','sim_en','repeaten']]
chdf = pd.read_csv('./temp/已檢查僅中文.csv', converters={"certain": literal_eval})
chdf = chdf[['brand_ch','certain']]
endf = pd.read_csv('./temp/已檢查僅英文.csv', converters={"certain": literal_eval})
endf = endf[['brand_en','certain']]

# %%
# 整理中+英 比對 英文資料

for i in tqdm(range(len(enchdf))):
    namelst = []
    for name, score in enchdf['sim_en'][i]:
        namelst.append(name)
    enchdf['sim_en'][i] = namelst
# Out:
#   0%|                                                  | 0/1217 [00:00<?, ?it/s]/var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/919473937.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enchdf['sim_en'][i] = namelst
# 100%|██████████████████████████████████████| 1217/1217 [00:03<00:00, 345.10it/s]

# %%
print('比對中英文後總數：',len(enchdf[(enchdf['repeat'] == 0) & (enchdf['repeaten'] == 0)]))
# Out:
# 比對中英文後總數： 1167

# %%
enchdf = enchdf[(enchdf['repeat'] == 0) & (enchdf['repeaten'] == 0)]
enchdf.reset_index(inplace=True)

# %%
enchdf = enchdf[['brand_ch','brand_en','cleaned_brand','sim_ch','sim_en']]

# %%
enchdf
# Out:
#      brand_ch            brand_en          cleaned_brand sim_ch   sim_en
# 0        妮傲絲翠             neo-tec            neo-tec妮傲絲翠     []       []
# 1         飛利浦             philips             philips飛利浦  [飛利浦]       []
# 2          專科               senka                senka專科   [專科]       []
# 3          芳珂               fancl                fancl芳珂     []  [fancl]
# 4          紅牛            red bull             red bull紅牛     []       []
# ...       ...                 ...                    ...    ...      ...
# 1162       樂格                 log                  log樂格     []       []
# 1163     陪心寵糧              nu4pet             nu4pet陪心寵糧     []       []
# 1164       渴達              tundra               tundra渴達     []       []
# 1165      御皇居               royal               royal御皇居  [御皇居]       []
# 1166      百貓喜  best feline friend  best feline friend百貓喜     []       []
#
# [1167 rows x 5 columns]

# %%
enchdf['similar'] = ''

for i in tqdm(range(len(enchdf))):
    # 若皆沒有相似則跳過
    if len(enchdf['sim_en'][i]) == 0 and len(enchdf['sim_ch'][i]) == 0:
        enchdf['similar'][i] = []
        continue
    
    enchdf['similar'][i] = []
    # 是否英文有相似
    if len(enchdf['sim_en'][i]) != 0:
        for name in enchdf['sim_en'][i]:
            idx = endf[endf['brand_en'] == name].index  # 取得在英文資料集的位置
            if len(idx) == 0: # 若沒有找到（在中+英有相似但不在英文資料集內）
                enchdf['similar'][i].append(name)
            else: # 如果有找到
                enchdf['similar'][i].append(name)
                for enname in endf['certain'][idx[0]]:
                    enchdf['similar'][i].append(enname) # 逐一加入
                endf.drop(idx[0], inplace = True) # 將資料刪除（因為已轉移至中+英）
                
    # 是否中文有相似
    if len(enchdf['sim_ch'][i]) != 0:
        for name in enchdf['sim_ch'][i]:
            idx = chdf[chdf['brand_ch'] == name].index # 取得在中文資料集的位置
            if len(idx) == 0: # 若沒有找到（在中+英有相似但不在英文資料集內）
                enchdf['similar'][i].append(name)
            else: # 如果有找到
                enchdf['similar'][i].append(name)
                for chname in chdf['certain'][idx[0]]:
                    enchdf['similar'][i].append(chname) # 逐一加入
                chdf.drop(idx[0], inplace = True) # 將資料刪除（因為已轉移至中+英）
# Out:
# 100%|█████████████████████████████████████| 1167/1167 [00:00<00:00, 4961.48it/s]

# %% [markdown]
# ## 合併

# %%
# 中英混合
enchdf = enchdf[['cleaned_brand', 'similar']]
enchdf
# Out:
#               cleaned_brand  similar
# 0               neo-tec妮傲絲翠       []
# 1                philips飛利浦    [飛利浦]
# 2                   senka專科     [專科]
# 3                   fancl芳珂  [fancl]
# 4                red bull紅牛       []
# ...                     ...      ...
# 1162                  log樂格       []
# 1163             nu4pet陪心寵糧       []
# 1164               tundra渴達       []
# 1165               royal御皇居    [御皇居]
# 1166  best feline friend百貓喜       []
#
# [1167 rows x 2 columns]

# %%
# 純中文
chdf
# Out:
#      brand_ch                         certain
# 0          元山                           [元山牌]
# 1         姍拉娜                              []
# 2          台鹽                        [臺鹽, 台塩]
# 3          舒潔                              []
# 4         龜甲萬                              []
# ...       ...                             ...
# 1301       華菱                              []
# 1302       上元                              []
# 1303    富基-10                              []
# 1304     一午一食                              []
# 1305       光泉  [光泉乳香世家, 光泉豆漿, 光泉頂級鮮奶優酪, 光泉鮮乳]
#
# [1137 rows x 2 columns]

# %%
# 純英文
endf
# Out:
#            brand_en                   certain
# 0            refine                        []
# 1          i'm meme                        []
# 2            chicco                        []
# 3             kirin                        []
# 4           cezanne                        []
# ...             ...                       ...
# 1254        van pur                        []
# 1255    sweep robot                        []
# 1256  malibu beauty                        []
# 1257   s.pellegrino                        []
# 1258        plantur  [plantur 21, plantur 39]
#
# [1174 rows x 2 columns]

# %%
# 純數字
numdf = oribrand[oribrand['original_brand'].str.isnumeric() == 1]
numdf.reset_index(inplace=True)
numdf['similar'] = ''
for i in range(len(numdf)):
    numdf['similar'][i] = []
numdf = numdf[['original_brand', 'similar']]
numdf
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3063883370.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numdf['similar'] = ''
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3063883370.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numdf['similar'][i] = []
#   original_brand similar
# 0            五五五      []
# 1           1028      []
# 2            360      []
# 3            080      []
# 4             零零      []
# 5           2080      []

# %%
enchdf = enchdf.rename({'cleaned_brand': 'brand'}, axis=1)
chdf = chdf.rename({'brand_ch': 'brand', 'certain': 'similar'}, axis=1)
endf = endf.rename({'brand_en': 'brand', 'certain': 'similar'}, axis=1)
numdf = numdf.rename({'original_brand': 'brand'}, axis=1)

# %%
finaldf = pd.concat([enchdf,chdf,endf,numdf])
finaldf.reset_index(inplace=True)
finaldf = finaldf[['brand', 'similar']]

# %%
finaldf
# Out:
#             brand  similar
# 0     neo-tec妮傲絲翠       []
# 1      philips飛利浦    [飛利浦]
# 2         senka專科     [專科]
# 3         fancl芳珂  [fancl]
# 4      red bull紅牛       []
# ...           ...      ...
# 3479         1028       []
# 3480          360       []
# 3481          080       []
# 3482           零零       []
# 3483         2080       []
#
# [3484 rows x 2 columns]

# %%
bddf = pd.read_csv('./temp/forfinaldf.csv')

# %%
bddf = bddf[['name', 'brand', 'clean_name', 'clean_brand', 'brand_ch', 'brand_en', 'cleaned_brand']]
bddf
# Out:
#                                     name          brand  \
# 0                          元山熱水瓶ys-540ap             元山
# 1                    356612@姍拉娜治痘洗面乳150g            姍拉娜
# 2                        台鹽海洋鹼性離子水 600ml             台鹽
# 3                           妮傲絲翠果酸深層保養乳液    NEO-TEC妮傲絲翠
# 4                舒潔棉柔舒適迪士尼抽取式衛生紙 100抽16入             舒潔
# ...                                  ...            ...
# 70041  惠而浦16公斤瓦斯型滾筒蒸氣(可堆疊)乾衣機8twgd6622hw  惠而浦 Whirlpool
# 70042                          康乃馨成人紙尿褲l            康乃馨
# 70043               日本芮芙茹零矽靈洗髮露460ml頭皮保養     芮芙茹 Reveur
# 70044                crest長效鎖白牙膏-輕柔鑽白99g          crest
# 70045             714171@雀巢咖啡三合一義式拿鐵16g*             雀巢
#
#                         clean_name    clean_brand brand_ch   brand_en  \
# 0                     元山熱水瓶ys540ap             元山       元山        NaN
# 1                         姍拉娜治痘洗面乳            姍拉娜      姍拉娜        NaN
# 2                        台鹽海洋鹼性離子水             台鹽       台鹽        NaN
# 3                     妮傲絲翠果酸深層保養乳液    neo-tec妮傲絲翠     妮傲絲翠    neo-tec
# 4                  舒潔棉柔舒適迪士尼抽取式衛生紙             舒潔       舒潔        NaN
# ...                            ...            ...      ...        ...
# 70041  惠而浦瓦斯型滾筒蒸氣可堆疊乾衣機8twgd6622hw  惠而浦 whirlpool      惠而浦  whirlpool
# 70042                    康乃馨成人紙尿褲l            康乃馨      康乃馨        NaN
# 70043              日本芮芙茹零矽靈洗髮露頭皮保養     芮芙茹 reveur      芮芙茹     reveur
# 70044              crest長效鎖白牙膏輕柔鑽白          crest      NaN      crest
# 70045                  雀巢咖啡三合一義式拿鐵             雀巢       雀巢        NaN
#
#       cleaned_brand
# 0                元山
# 1               姍拉娜
# 2                台鹽
# 3       neo-tec妮傲絲翠
# 4                舒潔
# ...             ...
# 70041  whirlpool惠而浦
# 70042           康乃馨
# 70043     reveur芮芙茹
# 70044         crest
# 70045            雀巢
#
# [70046 rows x 7 columns]

# %%
for i in range(len(bddf)):
    try:
        if math.isnan(bddf['brand_ch'][i]):
            bddf['brand_ch'][i] = ''
    except:
        pass
    try:
        if math.isnan(bddf['brand_en'][i]):
            bddf['brand_en'][i] = ''
    except:
        pass
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2856531506.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bddf['brand_en'][i] = ''
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/2856531506.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bddf['brand_ch'][i] = ''

# %%
bddf = bddf[['name', 'brand', 'clean_name', 'brand_ch', 'brand_en', 'cleaned_brand']]
bddf
# Out:
#                                     name          brand  \
# 0                          元山熱水瓶ys-540ap             元山
# 1                    356612@姍拉娜治痘洗面乳150g            姍拉娜
# 2                        台鹽海洋鹼性離子水 600ml             台鹽
# 3                           妮傲絲翠果酸深層保養乳液    NEO-TEC妮傲絲翠
# 4                舒潔棉柔舒適迪士尼抽取式衛生紙 100抽16入             舒潔
# ...                                  ...            ...
# 70041  惠而浦16公斤瓦斯型滾筒蒸氣(可堆疊)乾衣機8twgd6622hw  惠而浦 Whirlpool
# 70042                          康乃馨成人紙尿褲l            康乃馨
# 70043               日本芮芙茹零矽靈洗髮露460ml頭皮保養     芮芙茹 Reveur
# 70044                crest長效鎖白牙膏-輕柔鑽白99g          crest
# 70045             714171@雀巢咖啡三合一義式拿鐵16g*             雀巢
#
#                         clean_name brand_ch   brand_en cleaned_brand
# 0                     元山熱水瓶ys540ap       元山                       元山
# 1                         姍拉娜治痘洗面乳      姍拉娜                      姍拉娜
# 2                        台鹽海洋鹼性離子水       台鹽                       台鹽
# 3                     妮傲絲翠果酸深層保養乳液     妮傲絲翠    neo-tec   neo-tec妮傲絲翠
# 4                  舒潔棉柔舒適迪士尼抽取式衛生紙       舒潔                       舒潔
# ...                            ...      ...        ...           ...
# 70041  惠而浦瓦斯型滾筒蒸氣可堆疊乾衣機8twgd6622hw      惠而浦  whirlpool  whirlpool惠而浦
# 70042                    康乃馨成人紙尿褲l      康乃馨                      康乃馨
# 70043              日本芮芙茹零矽靈洗髮露頭皮保養      芮芙茹     reveur     reveur芮芙茹
# 70044              crest長效鎖白牙膏輕柔鑽白               crest         crest
# 70045                  雀巢咖啡三合一義式拿鐵       雀巢                       雀巢
#
# [70046 rows x 6 columns]

# %%
fbranlst = finaldf.copy(deep=True)

# %%
fbranlst['same'] = ''

# %%
tmplen = len(fbranlst)
for i in range(tmplen):
    for name in fbranlst['similar'][i]:
        fbranlst = fbranlst.append({
            "brand": name,
            "similar": [],
            "same": fbranlst['brand'][i]
        }, ignore_index=True)
# Out:
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# ...
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({
# /var/folders/xc/lbpw82tj4pd9lw15l1swq9040000gn/T/ipykernel_17758/3250581956.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   fbranlst = fbranlst.append({

# %%
for i in range(len(bddf)):
    searchres = fbranlst[fbranlst['brand'] == bddf['cleaned_brand'][i]]
    if len(searchres) == 0:
        print("index:", i)
        print("No Matched Search:", bddf['cleaned_brand'][i])
    elif len(searchres) == 1:
        samewd = fbranlst['same'][searchres.index[0]] 
        if samewd == '': # 是主值
            if bddf['brand'][i] not in fbranlst['similar'][searchres.index[0]]: # 如果未清洗的品牌名稱不在相似表內
                fbranlst['similar'][searchres.index[0]].append(bddf['brand'][i]) # 加入未清洗的名稱
        else: # 不是主值
            # 如果未清洗的品牌名稱不在主值相似表內
            if bddf['brand'][i] not in fbranlst['similar'][fbranlst[fbranlst['brand'] == samewd].index[0]]: 
                # 加入未清洗的名稱
                fbranlst['similar'][fbranlst[fbranlst['brand'] == samewd].index[0]].append(bddf['brand'][i]) 
    else:
        print("index:", i)
        print("Multiple Results:", bddf['cleaned_brand'][i])
        

print('----END----')
# Out:
# index: 1223
# Multiple Results: 生活
# index: 2249
# Multiple Results: 愛生活
# index: 2372
# Multiple Results: 生活
# index: 2998
# Multiple Results: 屏大
# index: 3594
# Multiple Results: 愛力
# index: 4821
# Multiple Results: 皇冠
# index: 5556
# Multiple Results: 生活
# index: 5724
# Multiple Results: 極淨適
# index: 6367
# Multiple Results: 生活
# index: 6594
# Multiple Results: 生活
# index: 7621
# Multiple Results: 生活
# index: 7758
# Multiple Results: 生活
# index: 10026
# Multiple Results: 屏科大
# index: 10263
# Multiple Results: 生活
# index: 10977
# Multiple Results: 生活
# index: 11340
# Multiple Results: 生活
# index: 11358
# Multiple Results: d-up
# index: 11497
# Multiple Results: 生活
# index: 13286
# Multiple Results: 生活
# index: 14302
# Multiple Results: d-up
# index: 14757
# Multiple Results: 生活
# index: 14881
# Multiple Results: 生活
# index: 15377
# Multiple Results: 屏科大
# index: 15516
# Multiple Results: 屏大
# index: 15766
# Multiple Results: 生活
# index: 16120
# Multiple Results: 生活
# index: 16170
# Multiple Results: 屏大
# index: 16742
# Multiple Results: 生活
# index: 17322
# Multiple Results: 屏科大
# index: 17486
# Multiple Results: 屏科大
# index: 17902
# No Matched Search: o'right歐萊德
# index: 18434
# Multiple Results: 生活
# index: 19092
# Multiple Results: 生活
# index: 19161
# Multiple Results: d-up
# index: 20149
# Multiple Results: 屏科大
# index: 20498
# Multiple Results: 極淨適
# index: 21046
# Multiple Results: 生活
# index: 21767
# Multiple Results: 生活
# index: 21839
# Multiple Results: 屏大
# index: 22070
# Multiple Results: 生活
# index: 22717
# Multiple Results: 生活
# index: 23819
# Multiple Results: 屏科大
# index: 23949
# Multiple Results: 生活
# index: 24362
# Multiple Results: 生活
# index: 25017
# Multiple Results: 屏科大
# index: 25024
# Multiple Results: 生活
# index: 25146
# Multiple Results: 生活
# index: 25320
# Multiple Results: 屏科大
# index: 25641
# Multiple Results: 生活
# index: 26057
# Multiple Results: 生活
# index: 26163
# Multiple Results: 生活
# index: 26598
# Multiple Results: 生活
# index: 27431
# Multiple Results: 生活
# index: 27471
# Multiple Results: 生活
# index: 27857
# Multiple Results: 生活
# index: 27991
# Multiple Results: 屏科大
# index: 28650
# Multiple Results: 生活
# index: 29750
# Multiple Results: 屏大
# index: 30348
# Multiple Results: 生活
# index: 30796
# Multiple Results: 生活
# index: 31301
# Multiple Results: d-up
# index: 31811
# Multiple Results: 屏大
# index: 32287
# Multiple Results: 生活
# index: 32471
# Multiple Results: 屏大
# index: 32707
# Multiple Results: 生活
# index: 32848
# Multiple Results: 屏科大
# index: 33220
# Multiple Results: 皇冠
# index: 33575
# No Matched Search:  100mountain百岳
# index: 33737
# Multiple Results: 生活
# index: 33809
# Multiple Results: 生活
# index: 34203
# Multiple Results: 屏科大
# index: 34389
# Multiple Results: 屏科大
# index: 36716
# Multiple Results: 生活
# index: 37018
# Multiple Results: 生活
# index: 37790
# No Matched Search: ‎d-up‎
# index: 37870
# Multiple Results: 生活
# index: 39409
# Multiple Results: 生活
# index: 40683
# Multiple Results: 屏科大
# index: 41921
# No Matched Search: o'right歐萊德
# index: 42395
# Multiple Results: 屏大
# index: 44728
# Multiple Results: 生活
# index: 45572
# Multiple Results: 生活
# index: 45863
# Multiple Results: d-up
# index: 47920
# Multiple Results: 屏大
# index: 48374
# Multiple Results: 屏科大
# index: 48646
# Multiple Results: 生活
# index: 48795
# Multiple Results: 屏科大
# index: 49174
# Multiple Results: 生活
# index: 49615
# Multiple Results: 生活
# index: 49907
# Multiple Results: 屏科大
# index: 50680
# Multiple Results: 生活
# index: 51088
# Multiple Results: 屏科大
# index: 51266
# Multiple Results: 生活
# index: 52118
# Multiple Results: d-up
# index: 53231
# Multiple Results: 生活
# index: 54141
# Multiple Results: 生活
# index: 54393
# Multiple Results: 屏科大
# index: 54995
# Multiple Results: d-up
# index: 55360
# Multiple Results: 生活
# index: 56739
# Multiple Results: 屏大
# index: 57509
# Multiple Results: 生活
# index: 57769
# Multiple Results: 皇冠
# index: 58384
# Multiple Results: 生活
# index: 59765
# Multiple Results: 生活
# index: 60301
# Multiple Results: d-up
# index: 61488
# Multiple Results: 生活
# index: 62452
# Multiple Results: 生活
# index: 62852
# Multiple Results: 生活
# index: 63011
# Multiple Results: 生活
# index: 63196
# Multiple Results: 屏科大
# index: 63238
# Multiple Results: 生活
# index: 65613
# No Matched Search: ‎d-up‎
# index: 65772
# Multiple Results: 生活
# index: 65790
# Multiple Results: 生活
# index: 65796
# Multiple Results: 屏大
# index: 67750
# Multiple Results: 生活
# index: 67822
# Multiple Results: 生活
# ----END----

# %%
finalreslst = fbranlst[fbranlst['same'] == '']

# %%
finalreslst = finalreslst[['brand', 'similar']]
finalreslst
# Out:
#             brand                          similar
# 0     neo-tec妮傲絲翠      [NEO-TEC妮傲絲翠, NEO-TEC 妮傲絲翠]
# 1      philips飛利浦  [飛利浦, 飛利浦 Philips, 飛利浦 PHILIPS]
# 2         senka專科                   [專科, SENKA 專科]
# 3         fancl芳珂         [fancl, FANCL 芳珂, FANCL]
# 4      red bull紅牛                    [紅牛 Red Bull]
# ...           ...                              ...
# 3479         1028                           [1028]
# 3480          360                            [360]
# 3481          080                            [080]
# 3482           零零                             [零零]
# 3483         2080                           [2080]
#
# [3484 rows x 2 columns]

# %%
finalreslst.to_csv('單一品牌內容.csv')
